# %%
import numpy as np
import pandas as pd

import json
import pickle

import os

from pprint import pprint

from datetime import datetime

# %%
# %%time

# Lee todos los archivos de la carpeta de "json_searches_spain"
# Crea una lista con los json

FOLDER_PATH = "json_searches_spain/" 

files = os.listdir(FOLDER_PATH)
jobs_results = list()
created_at = list()

for file in files:
    with open(file = f"{FOLDER_PATH}{file}", mode = "r") as f:
        x = json.load(f)
        
    if "jobs_results" in x:
        jobs_results.extend(x["jobs_results"])
        
    if "search_metadata" in x:
        date = x["search_metadata"]["created_at"]
        date = datetime.strptime(data["search_metadata"]["created_at"], "%Y-%m-%d %H:%M:%S UTC").date()
        created_at.append(date)        
    
print(len(jobs_results))
print(len(created_at))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <timed exec>:19
#
# NameError: name 'data' is not defined

# %%
df = pd.json_normalize(jobs_results)

del jobs_results

df.shape
# Out:
# (10, 12)

# %%
df = df.drop_duplicates("job_id")

df.shape
# Out:
# (10, 12)

# %%
description = """Buscamos un Administrador de sistemas para el departamento de IT de una empresa líder en el sector de software de gestión de residencias, centros de mayores y centros educativos.\n\nRequisitos:\n• 3 años de experiencia mínima administrando sistemas, Windows y Linux.\n• Experiencia en automatización de infraestructura.\n• Manejo y conocimiento alto de herramientas de automatización de infraestructura como Ansible o similar.\n• Manejo y conocimiento de herramientas de control de código tipo GIt, VSTS.\n• Conocimientos altos de scripting en powershell (u otras herramientas tipo Python).\n• Experiencia en testeo de los desarrollos hechos con las herramientas anteriores.\n• Experiencia en gestión de sistemas o infraestructuras en la nube.\n• Experiencia en gestión de infraestructura virtual, hipervisores de máquinas virtuales y de contenedores.\n• Conocimientos de seguridad de la infraestructura y servicios.\n• Configuración y manejo de firewalls.\n• Configuración de switches/routers.\n• Configuración... de clusters, sistemas de hiperconvergencia (Starwind).\n• Gestión de sistemas de backup, definición de planes de recuperación.\n• Aptitudes de la persona: Trabajo en equipo, organización, planificación, mentalidad de atención al usuario.\n• Idiomas: recomendable inglés.\n\nOfrecen:\n• Estabilidad, proyección, crecimiento, desarrollo profesional.\n• Formato 100% remoto.\n• Horario flexible de entrada y salida.\n• Revisiones salariales anuales.\n• Pluses de actividad"""

df[df["description"].str.extract(description)]
# Out:
#   title company_name location  via description job_highlights related_links  \
# 0   NaN          NaN      NaN  NaN         NaN            NaN           NaN
# 1   NaN          NaN      NaN  NaN         NaN            NaN           NaN
# 2   NaN          NaN      NaN  NaN         NaN            NaN           NaN
# 3   NaN          NaN      NaN  NaN         NaN            NaN           NaN
# 4   NaN          NaN      NaN  NaN         NaN            NaN           NaN
# 5   NaN          NaN      NaN  NaN         NaN            NaN           NaN
# 6   NaN          NaN      NaN  NaN         NaN            NaN           NaN
# 7   NaN          NaN      NaN  NaN         NaN            NaN           NaN
# 8   NaN          NaN      NaN  NaN         NaN            NaN           NaN
# 9   NaN          NaN      NaN  NaN         NaN            NaN           NaN
#
#   extensions job_id detected_extensions.posted_at  \
# 0        NaN    NaN                           NaN
# ...

# %%
df[df["description"] == df.value_counts("description").index[0]]
# Out:
#                        title         company_name    location             via  \
# 0  Desarrollador de Software  THE WISE SEEKER S.L    Spain     via Infoempleo
#
#                                          description  \
# 0  - Desarrollar soluciones de software asegurand...
#
#                                       job_highlights  \
# 0  [{'items': ['- Desarrollar soluciones de softw...
#
#                                        related_links  \
# 0  [{'link': 'http://www.thewiseseeker.com/', 'te...
#
#                                        extensions  \
# 0  [17 hours ago, Full-time, No degree mentioned]
#
#                                               job_id  \
# 0  eyJqb2JfdGl0bGUiOiJEZXNhcnJvbGxhZG9yIGRlIFNvZn...
#
#   detected_extensions.posted_at detected_extensions.schedule_type thumbnail
# 0                  17 hours ago                         Full-time       NaN

# %%
df1 = df.drop_duplicates("description").reset_index(drop = True)

df1.shape
# Out:
# (10, 12)

# %%
df1
# Out:
#                                  title                        company_name  \
# 0            Desarrollador de Software                 THE WISE SEEKER S.L
# 1            Desarrollador de Software   WITRON Logistik + Informatik GmbH
# 2            Desarrollador de software                                 CBT
# 3  Desarrollador/a de software en C/C+                 SEGULA Technologies
# 4                 Desarrollador de PHP                            Proconsi
# 5          DESARROLLADOR/A DE SOFTWARE                      TWIN INVERSORS
# 6                 Desarrollador de PHP                     Pista Cero S.L.
# 7            Desarrollador de Software                              WITRON
# 8                Desarrollador/a AS400           Profile Software Services
# 9            Desarrollador de software  Algoritmos, Procesos y Diseños S.A
#
#                                 location                via  \
# 0                               Spain        via Infoempleo
# ...
