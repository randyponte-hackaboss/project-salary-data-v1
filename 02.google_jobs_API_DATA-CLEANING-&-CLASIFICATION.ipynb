# %% [markdown]
# ### Depuración de los datos extraidos de la API

# %%
import numpy as np
import pandas as pd

from datetime import datetime, timedelta
import os
from time import sleep
import json
import re

import warnings
warnings.filterwarnings("ignore")

import pickle as pkl

from pprint import pprint

from libraries.preprocess import preprocess

# %%
# Ruta de la carpeta contenedora de los .json y listado de la misma
os.chdir(r"C:\Users\germa\Desktop\HACK A BOSS\proyecto_job-salary\data\data_1")
os.listdir()
# Out:
# ['64e341dd7d171a5eba5f3c42.json',
#  '64f4ca7ad5b1c59dfa1e7732.json',
#  '64f4ca7c2f542e4224aab4be.json',
#  '64f4ca7f47ccf1c95f8d12fa.json',
#  '64f4ca819bddf7898350eaed.json',
#  '64f4ca84a4be105f74c831b3.json',
#  '64f4ca883944b072edaf6675.json',
#  '64f4ca89654a8cab87d4f9d8.json',
#  '64f4ca91ce87f8713d381bc5.json',
#  '64f4ca93d3aba2853359280b.json',
#  '64f4ca948cd878d2e0f68b1f.json',
#  '64f4ca9637b24a4d8d864be5.json',
#  '64f4ca9b58762b793afe6c9c.json',
#  '64f4ca9edefa1370d22665eb.json',
#  '64f4ca9f66d81f806a8cc83c.json',
#  '64f4caa11d64ea5d0f8d39d2.json',
#  '64f4caa4ea144277cc6714c1.json',
#  '64f4caa6c640d29204d4f305.json',
#  '64f4caa84b91eb344a98f1e8.json',
#  '64f4caaab5961ef25aa8da1f.json',
#  '64f4caac8ccee041d362e327.json',
#  '64f4caaf95bf92a0b5aef06d.json',
#  '64f4cab08e02e477926dec14.json',
#  '64f4cab1969c0887bef341d7.json',
#  '64f4cab45b54ef90f18052aa.json',
#  '64f4cab52fe3022dda438416.json',
#  '64f4cab811c8816a1f348346.json',
#  '64f4cab9edb03482b22720fa.json',
#  '64f4cabb1988e567debe4aa8.json',
#  '64f4cabec56d93f41f351b23.json',
#  '64f4cac07f8361730085c865.json',
#  '64f4cac2c9de453e85fd510e.json',
#  '64f4cac4eb31ebaf33457671.json',
#  '64f4cacb87a0ee86fbd4ef31.json',
#  '64f4caceea144277cc6714df.json',
#  '64f4cad05119a6d181ea9792.json',
#  '64f4cad329d1777d8093854d.json',
#  '64f4cad510d744006d9fad4f.json',
#  '64f4cad766440a4a7a04e704.json',
#  '64f4cae27bea2779e93c94e7.json',
#  '64f4cae5e815affd6d61f64c.json',
#  '64f4cae8797ac6a5ba3eb0f0.json',
#  '64f4caec8ccee041d362e33f.json',
#  '64f4caee2c68785b9ff1f5c9.json',
#  '64f4caf00b5062bd54ea6426.json',
#  '64f4caf38ccee0426dddfe80.json',
#  '64f4caf40f98660a3f58b872.json',
#  '64f4caf67bea2779e93c94f3.json',
#  '64f4cafa7690dc92b08bd517.json',
#  '64f4cafde4a23d2cc25bb2b7.json',
#  '64f4cb001e803ffc9a9f02d2.json',
#  '64f4cb03d5a531e6d22139de.json',
#  '64f4cb05f55d7773607d26a2.json',
#  '64f4cb08f8f5f77b3a9cb942.json',
#  '64f4cb0c1c450a77ab49bd84.json',
#  '64f4cb12b7b1cc6d935033a7.json',
#  '64f4cb134055aa056605ec31.json',
#  '64f4cdd5b7b1cc6cf76c61e2.json',
#  '64f4cdd60f986609a63aea41.json',
#  '64f4cdd62e7d6bd4466bba95.json',
#  '64f4cdd79f55b343ae7cb0b5.json',
#  '64f4cdd7eb690f16a612c8d2.json',
#  '64f4cdd8af6304e42586f99a.json',
#  '64f4cdd93944b072edaf6748.json',
#  '64f4cdd94055aa056605ed09.json',
#  '64f4cdd9437af26198b2010a.json',
#  '64f4cdda681ebebbd68dc024.json',
#  '64f4cddb5b54ef90f1805350.json',
#  '64f4cddbf21801850e52f46e.json',
#  '64f4cddc9b64721c48f0511d.json',
#  '64f4cddca4be105f74c832b3.json',
#  '64f4cdde477c0e4dcef9f6e7.json',
#  '64f4cdde7bea2779e93c95f8.json',
#  '64f4cddf5f2203dfcf7d2561.json',
#  '64f4cde09d158664816ad78e.json',
#  '64f4cde124e88e9d00db4c8a.json',
#  '64f4cde1477c0e4dcef9f6e8.json',
#  '64f4cde3979054983d445c4f.json',
#  '64f4cde4224db17d3aa49096.json',
#  '64f4cde4fa867548edbb2c15.json',
#  '64f4cde6e93ff45395951c00.json',
#  '64f4cde74055aa04cb50517b.json',
#  '64f4cde9d04d6d8a7c64cff6.json',
#  '64f4cdea216a9d083b5523be.json',
#  ...]

# %%
# %%time

# Creamos un DataFrame con los datos contenidos en cada .json
dates = list()

df = pd.DataFrame()

for json_ in os.listdir():
    
    with open(json_, "br") as file:
        data = json.load(file) # Usar pickle arrojaba un error que json soluciona
        
    date = datetime.strptime(data["search_metadata"]["created_at"], "%Y-%m-%d %H:%M:%S UTC").date()

    try:

        df_ = pd.json_normalize(data["jobs_results"])

        for i in range(df_.shape[0]):

            dates.append(date)

        df = pd.concat([df, df_], ignore_index = True)

    except:
        pass


print(df.shape, len(dates))

os.chdir("../..")

df.to_csv("data/raw_data.csv", index = False, sep = ",") # Guardamos el DataFrame con todos los datos en bruto, (213303, 15)

with open("data/dates.pkl", "bw") as file: # Guardamos las fechas de la publicación de las búsquedas
    pkl.dump(dates, file)

# %%
# Cargamos el DataFrame con todos los datos en bruto y las fechas de publicación de los mismos
df = pd.read_csv("data/raw_data.csv")

with open("data/dates.pkl", "br") as file:
    dates = pkl.load(file)
    
df.shape
# Out:
# (213303, 15)

# %%
# Creamos "date_posted"
df["date_posted"] = dates

# Eliminamos duplicados
df = df.drop_duplicates("job_id").reset_index(drop = True) 

# Limpiamos "via"
for i in range(len(df["via"])):
    
    # Debido a valores NoneType, usamos try/except
    
    try:
        df.loc[i, "via"] = clean.clean_source(df.loc[i, "via"]) # Cada fila
        
    except:
        df.loc[i, "via"] = np.nan
    
# Limpiamos "location"
df["location"] = df["location"].apply(lambda x : clean.clean_location(x))

# Limpiamos "contract_type"
df["detected_extensions.schedule_type"] = df["detected_extensions.schedule_type"].apply(lambda x : clean.clean_contract_type(x))

# Limpiamos "created_date"
df["detected_extensions.posted_at"] = df["detected_extensions.posted_at"].apply(lambda x : clean.transform_date(x))

df["date_posted"] = [clean.get_date(x, y) for x, y in df[["date_posted", "detected_extensions.posted_at"]].values]

# Creamos "tech_skills"
for i in range(len(df["description"])):
    
    # Debido a valores NoneType, usamos try/except
    
    try:
        df.loc[i, "tech_skills"] = clean.get_skills(df.loc[i, "description"]) # Cada fila
        
    except:
        df.loc[i, "tech_skills"] = np.nan

# %% [markdown]
# ### ESPAÑA

# %%
# Filtramos el DataFrame por los trabajos cuyo país fuese España
lista_str_ = ["Spain", "España"]

for str_ in lista_str_:
    
    if str_ == "Spain":
        df_1 = df[df['location'].str.contains(str_, na = False)]
        
    elif str_ == "España":
        df_2 = df[df['location'].str.contains(str_, na = False)]
        
df_spain = pd.concat([df_1, df_2])

del df_1, df_2

# Guardamos dataset en bruto
df_spain.to_csv("data/spain_raw_data.csv", index = False, sep = ",")

# %%
df_spain
# Out:
#                                                    title  \
# 1      Software Developer (English - Functional Progr...
# 2                              Senior Software Developer
# 4                       SAP CPQ Software Developer (F/M)
# 5              Software Engineer, Developer Productivity
# 6      Senior Software Engineer, Competitive Intellig...
# ...                                                  ...
# 76688                             Arquitecto Azure Cloud
# 76689                                   Arquitecto Cloud
# 76690                                   Arquitecto Cloud
# 76691                                   Arquitecto Cloud
# 76692                                   Arquitecto Cloud
#
#                          company_name        location               via  \
# 1                      Stack Builders   Madrid, Spain  Jobs By Workable
# 2                    _external, Lumen   Madrid, Spain        Lumen Jobs
# 4                           Sartorius   Madrid, Spain         Sartorius
# 5                              Affirm   Madrid, Spain        Greenhouse
# 6                          Okta, Inc.           Spain              Okta
# ...                               ...             ...               ...
# 76688                       TD SYNNEX   Palma, España     Jobrapido.com
# 76689  Azertium IT Global Services SL  Madrid, España             BeBee
# 76690                             UST  Madrid, España             BeBee
# 76691               Decide Soluciones  Madrid, España             BeBee
# 76692     Krell Consulting & Training  Madrid, España             BeBee
#
#                                              description  \
# 1      Welcome to Stack Builders! We’re an empathetic...
# 2      About Lumen\nLumen is guided by our belief tha...
# 4      We are looking for an experienced Software Dev...
# 5      Developer Productivity engineering’s purpose i...
# 6      Get to know Okta\nOkta is The World’s Identity...
# ...                                                  ...
# 76688  ¡Es muy gratificante trabajar en una empresa e...
# 76689  Desde Azertium IT nos gustaría contar con los ...
# 76690  Seguimos buscando talento...y nos encantaría q...
# 76691  ¿A quién buscamos?\n\nActualmente buscamos un ...
# 76692  KRELL CONSULTING desearía incorporar a su equi...
#
#                                           job_highlights  \
# 1      [{'items': ["Welcome to Stack Builders! We’re ...
# 2      [{'items': ['About Lumen\nLumen is guided by o...
# 4      [{'items': ["We are looking for an experienced...
# 5      [{'items': ["Developer Productivity engineerin...
# 6      [{'items': ['Get to know Okta\nOkta is The Wor...
# ...                                                  ...
# 76688  [{'items': ['¡Es muy gratificante trabajar en ...
# 76689  [{'items': ['Desde Azertium IT nos gustaría co...
# 76690  [{'items': ['Seguimos buscando talento...y nos...
# 76691  [{'items': ['¿A quién buscamos?\n\nActualmente...
# 76692  [{'items': ['KRELL CONSULTING desearía incorpo...
#
#                                            related_links  \
# 1      [{'link': 'https://www.google.com/search?sca_e...
# 2      [{'link': 'https://www.google.com/search?sca_e...
# 4      [{'link': 'http://www.sartorius.com/', 'text':...
# 5      [{'link': 'http://www.affirm.com/', 'text': 'a...
# 6      [{'link': 'http://www.okta.com/', 'text': 'okt...
# ...                                                  ...
# 76688  [{'link': 'https://www.synnex.com/', 'text': '...
# 76689  [{'link': 'https://www.google.com/search?sca_e...
# 76690  [{'link': 'https://www.google.com/search?sca_e...
# 76691  [{'link': 'http://www.decidesoluciones.es/en',...
# 76692  [{'link': 'https://www.google.com/search?sca_e...
#
#                                                thumbnail  \
# 1                                                    NaN
# 2      https://encrypted-tbn0.gstatic.com/images?q=tb...
# 4                                                    NaN
# 5      https://encrypted-tbn0.gstatic.com/images?q=tb...
# 6                                                    NaN
# ...                                                  ...
# 76688  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 76689  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 76690  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 76691                                                NaN
# 76692  https://encrypted-tbn0.gstatic.com/images?q=tb...
#
#                                               extensions  \
# 1                           ['28 days ago', 'Full-time']
# 2                   ['Full-time', 'No degree mentioned']
# 4                                          ['Full-time']
# 5                           ['10 days ago', 'Full-time']
# 6      ['7 days ago', 'Full-time', 'No degree mention...
# ...                                                  ...
# 76688                                ['Tiempo completo']
# 76689                 ['hace 3 días', 'Tiempo completo']
# 76690                 ['hace 3 días', 'Tiempo completo']
# 76691                 ['hace 8 días', 'Tiempo completo']
# 76692                 ['hace 6 días', 'Tiempo completo']
#
#                                                   job_id  \
# 1      eyJqb2JfdGl0bGUiOiJTb2Z0d2FyZSBEZXZlbG9wZXIgKE...
# 2      eyJqb2JfdGl0bGUiOiJTZW5pb3IgU29mdHdhcmUgRGV2ZW...
# 4      eyJqb2JfdGl0bGUiOiJTQVAgQ1BRIFNvZnR3YXJlIERldm...
# 5      eyJqb2JfdGl0bGUiOiJTb2Z0d2FyZSBFbmdpbmVlciwgRG...
# 6      eyJqb2JfdGl0bGUiOiJTZW5pb3IgU29mdHdhcmUgRW5naW...
# ...                                                  ...
# 76688  eyJqb2JfdGl0bGUiOiJBcnF1aXRlY3RvIEF6dXJlIENsb3...
# 76689  eyJqb2JfdGl0bGUiOiJBcnF1aXRlY3RvIENsb3VkIiwiaH...
# 76690  eyJqb2JfdGl0bGUiOiJBcnF1aXRlY3RvIENsb3VkIiwiaH...
# 76691  eyJqb2JfdGl0bGUiOiJBcnF1aXRlY3RvIENsb3VkIiwiaH...
# 76692  eyJqb2JfdGl0bGUiOiJBcnF1aXRlY3RvIENsb3VkIiwiaH...
#
#       detected_extensions.posted_at detected_extensions.schedule_type  \
# 1                           28 days                         Full-time
# 2                               NaT                         Full-time
# 4                               NaT                         Full-time
# 5                           10 days                         Full-time
# 6                            7 days                         Full-time
# ...                             ...                               ...
# 76688                           NaT                   Tiempo completo
# 76689                        3 days                   Tiempo completo
# 76690                        3 days                   Tiempo completo
# 76691                        8 days                   Tiempo completo
# 76692                        6 days                   Tiempo completo
#
#       detected_extensions.work_from_home detected_extensions.salary  \
# 1                                    NaN                        NaN
# 2                                    NaN                        NaN
# 4                                    NaN                        NaN
# 5                                    NaN                        NaN
# 6                                    NaN                        NaN
# ...                                  ...                        ...
# 76688                                NaN                        NaN
# 76689                                NaN                        NaN
# 76690                                NaN                        NaN
# 76691                                NaN                        NaN
# 76692                                NaN                        NaN
#
#       detected_extensions.commute_time date_posted tech_skills
# 1                                  NaN  2023-08-06        Ruby
# 2                                  NaN  2023-09-03         NaN
# 4                                  NaN  2023-09-03         NaN
# 5                                  NaN  2023-08-24         NaN
# 6                                  NaN  2023-08-27         NaN
# ...                                ...         ...         ...
# 76688                              NaN  2023-09-03     [Azure]
# 76689                              NaN  2023-08-31         NaN
# 76690                              NaN  2023-08-31         NaN
# 76691                              NaN  2023-08-26         NaN
# 76692                              NaN  2023-08-28         NaN
#
# [27944 rows x 17 columns]

# %% [markdown]
# #### Limpieza "df_spain"

# %%
# Renombramos los nombres de las columnas
df_spain = clean.clean_column_names(df_spain)

# %%
# Nos quedamos con las columnas que nos interesan
df_spain = df_spain[["job_id", "title", "company_name", "location", "source", 
                     "description", "job_highlights", "date_posted", "contract_type",
                     "tech_skills"]]

# %%
df_spain
# Out:
#                                                   job_id  \
# 1      eyJqb2JfdGl0bGUiOiJTb2Z0d2FyZSBEZXZlbG9wZXIgKE...
# 2      eyJqb2JfdGl0bGUiOiJTZW5pb3IgU29mdHdhcmUgRGV2ZW...
# 4      eyJqb2JfdGl0bGUiOiJTQVAgQ1BRIFNvZnR3YXJlIERldm...
# 5      eyJqb2JfdGl0bGUiOiJTb2Z0d2FyZSBFbmdpbmVlciwgRG...
# 6      eyJqb2JfdGl0bGUiOiJTZW5pb3IgU29mdHdhcmUgRW5naW...
# ...                                                  ...
# 76688  eyJqb2JfdGl0bGUiOiJBcnF1aXRlY3RvIEF6dXJlIENsb3...
# 76689  eyJqb2JfdGl0bGUiOiJBcnF1aXRlY3RvIENsb3VkIiwiaH...
# 76690  eyJqb2JfdGl0bGUiOiJBcnF1aXRlY3RvIENsb3VkIiwiaH...
# 76691  eyJqb2JfdGl0bGUiOiJBcnF1aXRlY3RvIENsb3VkIiwiaH...
# 76692  eyJqb2JfdGl0bGUiOiJBcnF1aXRlY3RvIENsb3VkIiwiaH...
#
#                                                    title  \
# 1      Software Developer (English - Functional Progr...
# 2                              Senior Software Developer
# 4                       SAP CPQ Software Developer (F/M)
# 5              Software Engineer, Developer Productivity
# 6      Senior Software Engineer, Competitive Intellig...
# ...                                                  ...
# 76688                             Arquitecto Azure Cloud
# 76689                                   Arquitecto Cloud
# 76690                                   Arquitecto Cloud
# 76691                                   Arquitecto Cloud
# 76692                                   Arquitecto Cloud
#
#                          company_name        location            source  \
# 1                      Stack Builders   Madrid, Spain  Jobs By Workable
# 2                    _external, Lumen   Madrid, Spain        Lumen Jobs
# 4                           Sartorius   Madrid, Spain         Sartorius
# 5                              Affirm   Madrid, Spain        Greenhouse
# 6                          Okta, Inc.           Spain              Okta
# ...                               ...             ...               ...
# 76688                       TD SYNNEX   Palma, España     Jobrapido.com
# 76689  Azertium IT Global Services SL  Madrid, España             BeBee
# 76690                             UST  Madrid, España             BeBee
# 76691               Decide Soluciones  Madrid, España             BeBee
# 76692     Krell Consulting & Training  Madrid, España             BeBee
#
#                                              description  \
# 1      Welcome to Stack Builders! We’re an empathetic...
# 2      About Lumen\nLumen is guided by our belief tha...
# 4      We are looking for an experienced Software Dev...
# 5      Developer Productivity engineering’s purpose i...
# 6      Get to know Okta\nOkta is The World’s Identity...
# ...                                                  ...
# 76688  ¡Es muy gratificante trabajar en una empresa e...
# 76689  Desde Azertium IT nos gustaría contar con los ...
# 76690  Seguimos buscando talento...y nos encantaría q...
# 76691  ¿A quién buscamos?\n\nActualmente buscamos un ...
# 76692  KRELL CONSULTING desearía incorporar a su equi...
#
#                                           job_highlights date_posted  \
# 1      [{'items': ["Welcome to Stack Builders! We’re ...  2023-08-06
# 2      [{'items': ['About Lumen\nLumen is guided by o...  2023-09-03
# 4      [{'items': ["We are looking for an experienced...  2023-09-03
# 5      [{'items': ["Developer Productivity engineerin...  2023-08-24
# 6      [{'items': ['Get to know Okta\nOkta is The Wor...  2023-08-27
# ...                                                  ...         ...
# 76688  [{'items': ['¡Es muy gratificante trabajar en ...  2023-09-03
# 76689  [{'items': ['Desde Azertium IT nos gustaría co...  2023-08-31
# 76690  [{'items': ['Seguimos buscando talento...y nos...  2023-08-31
# 76691  [{'items': ['¿A quién buscamos?\n\nActualmente...  2023-08-26
# 76692  [{'items': ['KRELL CONSULTING desearía incorpo...  2023-08-28
#
#          contract_type tech_skills
# 1            Full-time        Ruby
# 2            Full-time         NaN
# 4            Full-time         NaN
# 5            Full-time         NaN
# 6            Full-time         NaN
# ...                ...         ...
# 76688  Tiempo completo     [Azure]
# 76689  Tiempo completo         NaN
# 76690  Tiempo completo         NaN
# 76691  Tiempo completo         NaN
# 76692  Tiempo completo         NaN
#
# [27944 rows x 10 columns]

# %%
# Perfil y especialidades de los trabajos
df_perfil_especialidad = pd.read_csv("data/StackMinimo - StackTec.csv", skiprows = 2).drop("Unnamed: 0", axis = 1)

df_perfil_especialidad
# Out:
#         Codigo         N1 Perfil                   N2 Especialidad  \
# 0      DESBACK      Desarrollador                          Backend
# 1          NaN                NaN                              NaN
# 2          NaN                NaN                              NaN
# 3          NaN                NaN                              NaN
# 4          NaN                NaN                              NaN
# 5          NaN                NaN                              NaN
# 6        DESBD      Desarrollador                    Base de datos
# 7          NaN                NaN                              NaN
# 8          NaN                NaN                              NaN
# 9       DESAPI      Desarrollador                             APIs
# 10       DESMO      Desarrollador                           Mobile
# 11         NaN                NaN                              NaN
# 12         NaN                NaN                              NaN
# 13         NaN                NaN                              NaN
# 14     DESFRMO      Desarrollador                   Frontend Movil
# 15     DESFRWE      Desarrollador                     Frontend Web
# 16         NaN                NaN                              NaN
# 17         NaN                NaN                              NaN
# 18     DESFULL      Desarrollador                       Full Stack
# 19         NaN                NaN                              NaN
# 20         NaN                NaN                              NaN
# 21         NaN                NaN                              NaN
# 22         NaN                NaN                              NaN
# 23         NaN                NaN                              NaN
# 24       DESIN      Desarrollador                      Integración
# 25         NaN                NaN                              NaN
# 26         NaN                NaN                              NaN
# 27         NaN                NaN                              NaN
# 28     DESPOBI      Desarrollador                          Liferay
# 29         NaN                NaN                              NaN
# 30     DESPOBI      Desarrollador                         Power BI
# 31      DEVOPS             Devops  SRE (Software Release Engineer)
# 32     DISGRAF          Diseñador                Diseñador Gráfico
# 33         NaN                NaN                              NaN
# 34         NaN                NaN                              NaN
# 35  INFRACLOUD    Infraestructura            Infraestructura cloud
# 36         NaN                NaN                              NaN
# 37         NaN                NaN                              NaN
# 38     INFRASO    Infraestructura              Sistemas Operativos
# 39    INFRASEG    Infraestructura                        Seguridad
# 40         NaN                NaN                              NaN
# 41    INFRAMAN    Infraestructura          Mantenimiento y Soporte
# 42         NaN                NaN   Administrador de Base de datos
# 43         NaN                NaN        Servidores y aplicaciones
# 44       QAFUN  Quality Assurance                 Tester funcional
# 45       QAUTO  Quality Assurance              Tester automatizada
# 46    GOPSCRUM  Gestión Operativa                     SCRUM Master
# 47       GOPPO  Gestión Operativa                    Product Owner
# 48       GOPCS  Gestión Operativa                 Customer Success
# 49      GOPGER  Gestión Operativa              Gerente de Proyecto
# 50      ESPDAT       Especialista                Analisis de Datos
# 51         NaN                NaN                              NaN
# 52         NaN                NaN                              NaN
# 53         NaN                NaN                              NaN
# 54         NaN                NaN                              NaN
# 55         NaN                NaN                              NaN
#
#                            N3 Tecnología predominante
# 0                                                .Net
# 1                                                Java
# 2                                              NodeJs
# 3                                              Phyton
# 4                                           QuickBase
# 5              Lanbda, Azure Functions, GCP Functions
# 6                                        Oracle Forms
# 7                                                 SQL
# 8                                                 SAP
# 9                                                 All
# 10                                            Flutter
# 11                                              IONIC
# 12                               Nativo iOS o Android
# 13                                       React Native
# 14                                    Angular & IONIC
# 15                                            Angular
# 16                                        Java Script
# 17                                              React
# 18                                     .Net & Angular
# 19                                   Phyton & Angular
# 20                                     Java & Angular
# 21                                   NodeJs & Angular
# 22                                       Java & React
# 23                                     NodeJs & React
# 24                                     CA Api Gateway
# 25                                                IBM
# 26                                           Oracle
# 27                                           Mulesoft
# 28                                              Front
# 29                                               Back
# 30                                                All
# 31                                 GCP, AWS and AZURE
# 32                                              UX/UI
# 33                                                 UX
# 34                                                 UI
# 35                       AWS, Kubernetes, Docker, EKS
# 36                     Azure, Kubernetes, Docker, AKS
# 37                            GCP, Kubernetes, Docker
# 38        Linux, Red Hat, Windows, Kubernetes, Docker
# 39                    Disciplina: Assesment y Pentest
# 40                             Firewalls, Security SW
# 41                       Jira, Softwares de monitoreo
# 42  MYSQL, Progress, Oracle, Base de datos relacio...
# 43   Servidores Web, Tuxedo, Web Logic, Jboss, Kibana
# 44       Azzure Devops, Jira. Metodologías de testing
# 45    Selenium, Katalon, Appium,Cucumber, Micro Focus
# 46           Jira, Azzure Devops, Metodologías ágiles
# 47           Jira, Azzure Devops, Metodologías ágiles
# 48           Jira, Azzure Devops, Metodologías ágiles
# 49           Jira, Azzure Devops, Metodologías ágiles
# 50                                           Power BI
# 51                                   Business Analyst
# 52                                                SAP
# 53                              Business Intelligence
# 54                                      Data modeling
# 55                               Oracle Datawarehouse

# %%
list_especialidad = df_perfil_especialidad["N2 Especialidad"].dropna().to_list()

# %%
list_especialidad = ["Backend",
                     "Base de datos",
                     "Bases de datos",
                     "APIs",
                     "Mobile",
                     "Frontend Movil",
                     "Frontend Web",
                     "Full Stack",
                     "Integración",
                     "Liferay",
                     "Power BI",
                     "Software Release Engineer",
                     "SRE",
                     "Diseñador Gráfico",
                     "Graphic Designer",
                     "Infraestructura cloud",
                     "Estructuras cloud",
                     "Sistemas Operativos",
                     "Seguridad",
                     "Mantenimiento y Soporte",
                     "Administrador de Base de datos",
                     "Servidores y aplicaciones",
                     "Tester funcional",
                     "Tester automatizada",
                     "SCRUM Master",
                     "Product Owner",
                     "Customer Success",
                     "Gerente de Proyecto",
                     "Analisis de Datos",
                     "Analista de Datos"]

# %%
dict_perfiles = {v : k for k, v in df_perfil_especialidad[["N1 Perfil ", "N2 Especialidad"]].dropna().values}

# %%
# Corrección de algunas keys
dict_perfiles = {'Backend': 'Desarrollador',
                 'Base de datos': 'Desarrollador',
                 'APIs': 'Desarrollador',
                 'Mobile': 'Desarrollador',
                 'Frontend Movil': 'Desarrollador',
                 'Frontend Web': 'Desarrollador',
                 'Full Stack': 'Desarrollador',
                 'Integración': 'Desarrollador',
                 'Liferay': 'Desarrollador',
                 'Power BI': 'Desarrollador',
                 'Software Release Engineer': 'Devops',
                 'Diseñador Gráfico': 'Diseñador',
                 'Infraestructura cloud': 'Infraestructura',
                 'Sistemas Operativos': 'Infraestructura',
                 'Seguridad': 'Infraestructura',
                 'Mantenimiento y Soporte': 'Infraestructura',
                 'Tester funcional': 'Quality Assurance',
                 'Tester automatizada': 'Quality Assurance',
                 'SCRUM Master': 'Gestión Operativa',
                 'Product Owner': 'Gestión Operativa',
                 'Customer Success': 'Gestión Operativa',
                 'Gerente de Proyecto': 'Gestión Operativa',
                 'Analisis de Datos': 'Especialista'}

# %%
# Funciones para generar las columnas de perfil y especialidad
def get_especialidad(string, list_especialidad):
    
    especialidades = list({especialidad for especialidad in list_especialidad if especialidad.lower() in string.lower()})
    
    return especialidades if especialidades else np.nan

def get_perfil(lista, dict_perfiles):
    
    perfiles = list({v for k, v in dict_perfiles.items() if k in lista})
    
    return perfiles if perfiles else np.nan

# %%
# Funciones para generar las columnas de años de experiencia y nivel de experiencia
def find_years_of_experience(string: str):
    
    list_strings = ["años de", "years of", "years experience", "años experiencia"]
    
    string = string.lower()
    
    years = [string[string.find(s) - 5 : string.find(s) + len(s) + 1] for s in list_strings if string.find(s) != -1]
    
    numeros = [re.findall(r"\d+", y) for y in years]

    numeros = [[int(n) for n in num if 0 < int(n) < 13] for num in numeros]
    
    numeros = [max(num) if num else np.nan for num in numeros]

    return max(numeros) if numeros else np.nan


def experience_level(num):
    
    if not pd.isna(num):
    
        if num < 2:
            return "Junior"
        elif num <= 4:
            return "Semi-Senior"
        elif num < 8:
            return "Senior"
        else:
            return "Leader"
        
    else:
        return np.nan

# %%
df_spain["job_specialization"] = df_spain["description"].apply(lambda x : get_especialidad(x, list_especialidad = list_especialidad) if not pd.isna(x) else None)
df_spain["job_profile"] = df_spain["description"].apply(lambda x : get_perfil(x, dict_perfiles = dict_perfiles) if not pd.isna(x) else None)

# %%
df_spain["experience"] = df_spain["description"].apply(lambda x : find_years_of_experience(x) if not pd.isna(x) else x)
df_spain["experience_level"] = df_spain["experience"].apply(lambda x : experience_level(x))

# %%
# Actualizamos "contract_type"
df_spain["contract_type"] = df_spain["contract_type"]\
                            .apply(lambda x : "Full-time" if x == "Tiempo completo" else x)

# Creamos "remote_work"
def get_remote_work(string):
    
    resultados = list()
    
    if "remoto" in string or "remote work" in string or "remote" in string:
        
        resultados.append("Remoto")
        
    elif "hibrido" in string or "hybrid" in string or "híbrido" in string:
        
        resultados.append("Hibrido")
        
    elif "presencial" in string or "in-office" in string:
        
        resultados.append("Presencial")
        
    else:
        return np.nan
        
    return resultados

df_spain["remote_work"] = df_spain["description"].apply(lambda x : get_remote_work(x))

# Actualizamos "location"
# ¡PENDIENTE, CONSULTAR CON DANI!
# ACTUALIZADO en la librería de preprocesamiento para el pipeline

# %%
df_spain = df_spain[["job_id", "experience", "experience_level", "description", "job_specialization",
                     "job_profile", "remote_work", "tech_skills", "title", "company_name", "location", "source",
                     "date_posted", "contract_type"]]

# Guardamos los datos limpios (falta alguna que otra corrección)
df_spain.to_csv("data/spain_cleaned_data.csv", index = False, sep = ",")

# %%
df_spain
# Out:
#                                                   job_id  country  experience  \
# 1      eyJqb2JfdGl0bGUiOiJTb2Z0d2FyZSBEZXZlbG9wZXIgKE...    Spain         NaN
# 2      eyJqb2JfdGl0bGUiOiJTZW5pb3IgU29mdHdhcmUgRGV2ZW...    Spain         NaN
# 4      eyJqb2JfdGl0bGUiOiJTQVAgQ1BRIFNvZnR3YXJlIERldm...    Spain         NaN
# 5      eyJqb2JfdGl0bGUiOiJTb2Z0d2FyZSBFbmdpbmVlciwgRG...    Spain         NaN
# 6      eyJqb2JfdGl0bGUiOiJTZW5pb3IgU29mdHdhcmUgRW5naW...    Spain         NaN
# ...                                                  ...      ...         ...
# 76688  eyJqb2JfdGl0bGUiOiJBcnF1aXRlY3RvIEF6dXJlIENsb3...   España         2.0
# 76689  eyJqb2JfdGl0bGUiOiJBcnF1aXRlY3RvIENsb3VkIiwiaH...   España         NaN
# 76690  eyJqb2JfdGl0bGUiOiJBcnF1aXRlY3RvIENsb3VkIiwiaH...   España         NaN
# 76691  eyJqb2JfdGl0bGUiOiJBcnF1aXRlY3RvIENsb3VkIiwiaH...   España         NaN
# 76692  eyJqb2JfdGl0bGUiOiJBcnF1aXRlY3RvIENsb3VkIiwiaH...   España         4.0
#
#       experience_level                                        description  \
# 1                  NaN  Welcome to Stack Builders! We’re an empathetic...
# 2                  NaN  About Lumen\nLumen is guided by our belief tha...
# 4                  NaN  We are looking for an experienced Software Dev...
# 5                  NaN  Developer Productivity engineering’s purpose i...
# 6                  NaN  Get to know Okta\nOkta is The World’s Identity...
# ...                ...                                                ...
# 76688      Semi-Senior  ¡Es muy gratificante trabajar en una empresa e...
# 76689              NaN  Desde Azertium IT nos gustaría contar con los ...
# 76690              NaN  Seguimos buscando talento...y nos encantaría q...
# 76691              NaN  ¿A quién buscamos?\n\nActualmente buscamos un ...
# 76692      Semi-Senior  KRELL CONSULTING desearía incorporar a su equi...
#
#              job_specialization                         job_profile  \
# 1                           NaN                                 NaN
# 2                           NaN                                 NaN
# 4         [Product Owner, APIs]  [Desarrollador, Gestión Operativa]
# 5                           NaN                                 NaN
# 6                           NaN                                 NaN
# ...                         ...                                 ...
# 76688               [Seguridad]                                 NaN
# 76689          [Bases de datos]                                 NaN
# 76690                       NaN                                 NaN
# 76691  [Integración, Seguridad]                     [Desarrollador]
# 76692               [Seguridad]                   [Infraestructura]
#
#         remote_work tech_skills  \
# 1          [Remoto]        Ruby
# 2               NaN         NaN
# 4         [Hibrido]         NaN
# 5               NaN         NaN
# 6               NaN         NaN
# ...             ...         ...
# 76688     [Hibrido]     [Azure]
# 76689           NaN         NaN
# 76690           NaN         NaN
# 76691           NaN         NaN
# 76692  [Presencial]         NaN
#
#                                                    title  \
# 1      Software Developer (English - Functional Progr...
# 2                              Senior Software Developer
# 4                       SAP CPQ Software Developer (F/M)
# 5              Software Engineer, Developer Productivity
# 6      Senior Software Engineer, Competitive Intellig...
# ...                                                  ...
# 76688                             Arquitecto Azure Cloud
# 76689                                   Arquitecto Cloud
# 76690                                   Arquitecto Cloud
# 76691                                   Arquitecto Cloud
# 76692                                   Arquitecto Cloud
#
#                          company_name        location            source  \
# 1                      Stack Builders   Madrid, Spain  Jobs By Workable
# 2                    _external, Lumen   Madrid, Spain        Lumen Jobs
# 4                           Sartorius   Madrid, Spain         Sartorius
# 5                              Affirm   Madrid, Spain        Greenhouse
# 6                          Okta, Inc.           Spain              Okta
# ...                               ...             ...               ...
# 76688                       TD SYNNEX   Palma, España     Jobrapido.com
# 76689  Azertium IT Global Services SL  Madrid, España             BeBee
# 76690                             UST  Madrid, España             BeBee
# 76691               Decide Soluciones  Madrid, España             BeBee
# 76692     Krell Consulting & Training  Madrid, España             BeBee
#
#       date_posted contract_type
# 1      2023-08-06     Full-time
# 2      2023-09-03     Full-time
# 4      2023-09-03     Full-time
# 5      2023-08-24     Full-time
# 6      2023-08-27     Full-time
# ...           ...           ...
# 76688  2023-09-03     Full-time
# 76689  2023-08-31     Full-time
# 76690  2023-08-31     Full-time
# 76691  2023-08-26     Full-time
# 76692  2023-08-28     Full-time
#
# [27944 rows x 15 columns]
