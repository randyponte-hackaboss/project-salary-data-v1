# %% [markdown]
# ### Pipeline preprocesamiento de datos

# %%
import pandas as pd

# Omitir warnings
import warnings
warnings.filterwarnings("ignore")

# Librería creada
from libraries.preprocess import preprocess
from libraries.preprocess import pipeline

# %%
# %%time

df = pipeline.pipeline(funciones = pipeline.funciones)

df = df[df["country"] == "Spain"].reset_index()
# Out:
# <function date_posted at 0x00000166B17B2160>
# <function job_id at 0x00000166B17B21F0>
# <function source at 0x00000166B17B2280>
# <function location at 0x00000166B17B2310>
# <function contract_type at 0x00000166B17B23A0>
# <function created_date at 0x00000166B17B2430>
# <function update_date_posted at 0x00000166B17B24C0>
# <function tech_skills at 0x00000166B17B2670>
# <function especialidad_perfil at 0x00000166B175DEE0>
# <function years_experience at 0x00000166B175DF70>
# <function remote_work at 0x00000166B17B20D0>
# <function update_contract_type at 0x00000166B17B2550>
# <function update_location_latam_spain at 0x00000166B17B25E0>
# CPU times: total: 13min 1s
# Wall time: 20min 25s

# %%
df = df.rename(columns = {"experience_level" : "experience_levels",
                          "job_specialization" : "Especialidad",
                          "job_profile" : "Perfil"})
df
# Out:
#        index                                             job_id country  \
# 0          1  eyJqb2JfdGl0bGUiOiJTb2Z0d2FyZSBEZXZlbG9wZXIgKE...   Spain
# 1          2  eyJqb2JfdGl0bGUiOiJTZW5pb3IgU29mdHdhcmUgRGV2ZW...   Spain
# 2          4  eyJqb2JfdGl0bGUiOiJTQVAgQ1BRIFNvZnR3YXJlIERldm...   Spain
# 3          5  eyJqb2JfdGl0bGUiOiJTb2Z0d2FyZSBFbmdpbmVlciwgRG...   Spain
# 4          6  eyJqb2JfdGl0bGUiOiJTZW5pb3IgU29mdHdhcmUgRW5naW...   Spain
# ...      ...                                                ...     ...
# 27939  95123  eyJqb2JfdGl0bGUiOiJFc3BlY2lhbGlzdGEgZW4gYmFzZX...   Spain
# 27940  95124  eyJqb2JfdGl0bGUiOiJUw6ljbmljby9hIGVzcGVjaWFsaX...   Spain
# 27941  95125  eyJqb2JfdGl0bGUiOiJFc3BlY2lhbGlzdGEgZW4gU2lzdG...   Spain
# 27942  95126  eyJqb2JfdGl0bGUiOiJUw6ljbmljbyBTYXQgRXhwZXJ0by...   Spain
# 27943  95149  eyJqb2JfdGl0bGUiOiJJbmdlbmllcm8gQ3liZXIgLSBDbG...   Spain
#
#        experience experience_levels  \
# 0             NaN               NaN
# 1             NaN               NaN
# 2             NaN               NaN
# 3             NaN               NaN
# 4             NaN               NaN
# ...           ...               ...
# 27939         NaN               NaN
# 27940         NaN               NaN
# 27941         NaN               NaN
# 27942         NaN               NaN
# 27943         NaN               NaN
#
#                                              description  \
# 0      Welcome to Stack Builders! We’re an empathetic...
# 1      About Lumen\nLumen is guided by our belief tha...
# 2      We are looking for an experienced Software Dev...
# 3      Developer Productivity engineering’s purpose i...
# 4      Get to know Okta\nOkta is The World’s Identity...
# ...                                                  ...
# 27939  dos puestos de especialista en bases de datos ...
# 27940  Grupo Sermicro es una empresa de referencia de...
# 27941  CIDETEC seleccionará a una persona para incorp...
# 27942  QUIENES SOMOS\n\nEn Iesmat, somos especialista...
# 27943  Descripción de la empresa\n\nDevoteam es una c...
#
#                 Especialidad                              Perfil remote_work  \
# 0                        NaN                                 NaN    [Remoto]
# 1                        NaN                                 NaN         NaN
# 2      [Product Owner, APIs]  [Desarrollador, Gestión Operativa]   [Hibrido]
# 3                        NaN                                 NaN         NaN
# 4                        NaN                                 NaN         NaN
# ...                      ...                                 ...         ...
# 27939       [Bases de datos]                                 NaN         NaN
# 27940            [Seguridad]                                 NaN         NaN
# 27941                    NaN                                 NaN         NaN
# 27942                    NaN                                 NaN         NaN
# 27943            [Seguridad]                   [Infraestructura]    [Remoto]
#
#                            tech_skills  \
# 0                               [Ruby]
# 1               [Azure, Redux, Spring]
# 2      [.NET, Python, REST, SOAP, SQL]
# 3                        [AWS, GitHub]
# 4                                   []
# ...                                ...
# 27939                               []
# 27940                               []
# 27941                               []
# 27942                               []
# 27943                               []
#
#                                                    title       company_name  \
# 0      Software Developer (English - Functional Progr...     Stack Builders
# 1                              Senior Software Developer   _external, Lumen
# 2                       SAP CPQ Software Developer (F/M)          Sartorius
# 3              Software Engineer, Developer Productivity             Affirm
# 4      Senior Software Engineer, Competitive Intellig...         Okta, Inc.
# ...                                                  ...                ...
# 27939  Especialista en bases de datos y en redes info...  jobzem (13104116)
# 27940                    Técnico/a especialista en redes     Grupo Sermicro
# 27941                    Especialista en Sistema y Redes            CIDETEC
# 27942      Técnico Sat Experto en Redes y Comunicaciones             IESMAT
# 27943                   Ingeniero Cyber - Cloud (Junior)           Devoteam
#
#           location            source date_posted contract_type
# 0         [Madrid]  Jobs By Workable  2023-08-06     Full-time
# 1         [Madrid]        Lumen Jobs  2023-09-03     Full-time
# 2         [Madrid]         Sartorius  2023-09-03     Full-time
# 3         [Madrid]        Greenhouse  2023-08-24     Full-time
# 4               []              Okta  2023-08-27     Full-time
# ...            ...               ...         ...           ...
# 27939     [Madrid]     Jobrapido.com  2023-08-26     Full-time
# 27940  [Barcelona]         Worksinit  2023-09-03     Full-time
# 27941           []             BeBee  2023-08-27    Contractor
# 27942           []            Joblum  2023-08-29     Full-time
# 27943     [Madrid]          LinkedIn  2023-08-29     Full-time
#
# [27944 rows x 16 columns]

# %%
df.to_csv("data/spain_cleaned_data.csv", index = False, sep = ",")

# %%
################################################################################################################################
