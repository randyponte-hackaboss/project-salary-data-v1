# %% [markdown]
# ### Pipeline preprocesamiento de datos

# %%
import pandas as pd
import numpy as np

# Omitir warnings
import warnings
warnings.filterwarnings("ignore")

# Librería creada
from libraries.preprocess import preprocess
from libraries.preprocess import pipeline

# %%
df_spain = pd.read_csv("data/extracted/extraction_2023-11-21_spain.csv")

# Eliminamos descripciones de ofertas que son idénticas y por lo tanto son las mismas aunque tenga distinto job_id
df_spain = df_spain.drop_duplicates(subset = "description").reset_index(drop = True)

# %%
# %%time

df = pipeline.pipeline(funciones = pipeline.funciones, df = df_spain)
# Out:
# <function date_posted at 0x000001CDAD19C310>
# <function normalize_title at 0x000001CDAD19C3A0>
# <function source at 0x000001CDAD19C430>
# <function fix_company_name at 0x000001CDAD19C0D0>
# <function location at 0x000001CDAD19C4C0>
# <function contract_type at 0x000001CDAD19C550>
# <function created_date at 0x000001CDAD19C5E0>
# <function update_date_posted at 0x000001CDAD19C670>
# <function tech_skills at 0x000001CDAD19C820>
# <function especialidad_perfil at 0x000001CDAD11EF70>
# <function years_experience at 0x000001CDAD19C040>
# <function remote_work at 0x000001CDAD19C280>
# <function email at 0x000001CDAD19C160>
# <function update_contract_type at 0x000001CDAD19C700>
# <function update_location_latam_spain at 0x000001CDAD19C790>
# CPU times: total: 13.4 s
# Wall time: 1min 3s

# %%
# df = df.rename(columns = {"experience_level" : "experience_levels",
#                           "job_specialization" : "Especialidad",
#                           "job_profile" : "Perfil"})
# df
# Out:
#                                                  job_id country  experience  \
# 0     eyJqb2JfdGl0bGUiOiJEZXNhcnJvbGxhZG9yL2EgZGUgU2...   Spain         5.0
# 1     eyJqb2JfdGl0bGUiOiJEZXNhcnJvbGxhZG9yL2EgZGUgU2...   Spain         3.0
# 2     eyJqb2JfdGl0bGUiOiJEZXNhcnJvbGxhZG9yIGRlIGJhY2...   Spain         5.0
# 3     eyJqb2JfdGl0bGUiOiJEZXNhcnJvbGxhZG9yIGRlIGZyb2...   Spain         6.0
# 4     eyJqb2JfdGl0bGUiOiJERVNBUlJPTExBRE9SL0EgRlJPTl...   Spain         2.0
# ...                                                 ...     ...         ...
# 2024  eyJqb2JfdGl0bGUiOiJEYmEgUmFjIE9yYWNsZSwgTWFkcm...   Spain         5.0
# 2025  eyJqb2JfdGl0bGUiOiJEQkEgT3JhY2xlIFJlbW90byIsIm...   Spain         NaN
# 2026  eyJqb2JfdGl0bGUiOiJEQkEgT3JhY2xlIiwiaHRpZG9jaW...   Spain         NaN
# 2027  eyJqb2JfdGl0bGUiOiJTd2lmdCBEZXZlbG9wZXIgSMOtYn...   Spain         4.0
# 2028  eyJqb2JfdGl0bGUiOiJpT1MgKFNXSUZUKSBEZXZlbG9wZX...   Spain         4.0
#
# ...

# %%
df.to_csv("data/cleaned/spain_cleaned_data_2023-11-21.csv", index = False, sep = ",")

# %%
################################################################################################################################
