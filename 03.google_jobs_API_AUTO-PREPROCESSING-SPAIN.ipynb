# %% [markdown]
# ### Pipeline preprocesamiento de datos

# %%
import pandas as pd
import numpy as np

# Omitir warnings
import warnings
warnings.filterwarnings("ignore")

# Librería creada
from libraries.preprocess import preprocess
from libraries.preprocess import pipeline

# %%
df_spain = pd.read_csv("data/extracted/spain_raw_data.csv")

# Eliminamos descripciones de ofertas que son idénticas y por lo tanto son las mismas aunque tenga distinto job_id
df_spain = df_spain.drop_duplicates(subset = "description").reset_index(drop = True)

# %%
# %%time

df = pipeline.pipeline(funciones = pipeline.funciones, df = df_spain)
# Out:
# <function date_posted at 0x0000020A13E08310>
# <function normalize_title at 0x0000020A13E083A0>
# <function source at 0x0000020A13E08430>
# <function fix_company_name at 0x0000020A13E080D0>
# <function location at 0x0000020A13E084C0>
# <function contract_type at 0x0000020A13E08550>
# <function created_date at 0x0000020A13E085E0>
# <function update_date_posted at 0x0000020A13E08670>
# <function tech_skills at 0x0000020A13E08820>
# <function especialidad_perfil at 0x0000020A13D74F70>
# <function years_experience at 0x0000020A13E08040>
# <function remote_work at 0x0000020A13E08280>
# <function email at 0x0000020A13E08160>
# <function update_contract_type at 0x0000020A13E08700>
# <function update_location_latam_spain at 0x0000020A13E08790>
# CPU times: total: 2min 47s
# Wall time: 14min 20s

# %%
df = df.rename(columns = {"experience_level" : "experience_levels",
                          "job_specialization" : "Especialidad",
                          "job_profile" : "Perfil"})
df
# Out:
#                                                   job_id country  experience  \
# 0      eyJqb2JfdGl0bGUiOiJTb2Z0d2FyZSBEZXZlbG9wZXIgKE...   Spain         1.0
# 1      eyJqb2JfdGl0bGUiOiJTZW5pb3IgU29mdHdhcmUgRGV2ZW...   Spain         NaN
# 2      eyJqb2JfdGl0bGUiOiJTQVAgQ1BRIFNvZnR3YXJlIERldm...   Spain         5.0
# 3      eyJqb2JfdGl0bGUiOiJTb2Z0d2FyZSBFbmdpbmVlciwgRG...   Spain         2.0
# 4      eyJqb2JfdGl0bGUiOiJTZW5pb3IgU29mdHdhcmUgRW5naW...   Spain         NaN
# ...                                                  ...     ...         ...
# 16269  eyJqb2JfdGl0bGUiOiJDbG91ZCBTb2x1dGlvbnMgQXJjaG...   Spain         NaN
# 16270  eyJqb2JfdGl0bGUiOiJBZG1pbmlzdHJhZG9yL2EgZGUgSW...   Spain         3.0
# 16271  eyJqb2JfdGl0bGUiOiJBcnF1aXRlY3RvIEF6dXJlIENsb3...   Spain         2.0
# 16272  eyJqb2JfdGl0bGUiOiJBcnF1aXRlY3RvIENsb3VkIiwiaH...   Spain         NaN
# 16273  eyJqb2JfdGl0bGUiOiJBcnF1aXRlY3RvIENsb3VkIiwiaH...   Spain         4.0
#
#       experience_levels                                        description  \
# 0                Junior  Welcome to Stack Builders! We’re an empathetic...
# 1                Senior  About Lumen\nLumen is guided by our belief tha...
# 2                Senior  We are looking for an experienced Software Dev...
# 3           Semi-Senior  Developer Productivity engineering’s purpose i...
# 4                Senior  Get to know Okta\nOkta is The World’s Identity...
# ...                 ...                                                ...
# 16269            Leader  Born back in the day as an open source platfor...
# 16270       Semi-Senior  Administrador/a de Infraestructura y Arquitect...
# 16271       Semi-Senior  ¡Es muy gratificante trabajar en una empresa e...
# 16272            Senior  Desde Azertium IT nos gustaría contar con los ...
# 16273       Semi-Senior  ¿A quién buscamos?\n\nActualmente buscamos un ...
#
#       email                                       Especialidad  \
# 0       NaN                                          [Backend]
# 1       NaN         [SRE (Software Release Engineer), Backend]
# 2       NaN                              [Backend, Salesforce]
# 3       NaN                            [Infraestructura cloud]
# 4       NaN                                                NaN
# ...     ...                                                ...
# 16269   NaN                    [Infraestructura cloud, Mobile]
# 16270   NaN  [Infraestructura cloud, Arquitecto de Software...
# 16271   NaN  [Mantenimiento y Soporte, Marketing, Mobile, S...
# 16272   NaN  [SRE (Software Release Engineer), Arquitecto C...
# 16273   NaN  [SRE (Software Release Engineer), Arquitecto d...
#
#                                                Perfil   remote_work  \
# 0                                     [Desarrollador]      [Remoto]
# 1                             [Devops, Desarrollador]           NaN
# 2                       [Especialista, Desarrollador]     [Hibrido]
# 3                                   [Infraestructura]           NaN
# 4                                                 NaN           NaN
# ...                                               ...           ...
# 16269                [Infraestructura, Desarrollador]      [Remoto]
# 16270                [Infraestructura, Desarrollador]  [Presencial]
# 16271  [Infraestructura, Especialista, Desarrollador]     [Hibrido]
# 16272        [Infraestructura, Devops, Desarrollador]           NaN
# 16273        [Infraestructura, Devops, Desarrollador]           NaN
#
#                                              tech_skills  \
# 0                   [Ruby, Health, Programming, Spanish]
# 1      [Azure, Redux, Spring, Design, Drupal, Managem...
# 2            [.NET, Python, REST, SOAP, SQL, Sales, SAP]
# 3                [AWS, GitHub, Design, Engineering, Git]
# 4                                                     []
# ...                                                  ...
# 16269  [Azure, Docker, Linux, Engineering, Health, In...
# 16270                                       [AWS, Azure]
# 16271                 [Azure, Microsoft, Sales, Samsung]
# 16272                 [Azure, Dynatrace, SQL, Microsoft]
# 16273           [AWS, Azure, Integración, Java, MongoDB]
#
#                                                    title       company_name  \
# 0      Software Developer (English - Functional Progr...     Stack Builders
# 1                              Senior Software Developer   _External, Lumen
# 2                       SAP CPQ Software Developer (F/M)          Sartorius
# 3              Software Engineer, Developer Productivity             Affirm
# 4      Senior Software Engineer, Competitive Intellig...         Okta, Inc.
# ...                                                  ...                ...
# 16269                          Cloud Solutions Architect         Opennebula
# 16270  Administrador/a de Infraestructura y Arquitect...    Banco Santander
# 16271                             Arquitecto Azure Cloud          Td Synnex
# 16272                                   Arquitecto Cloud        Azertium IT
# 16273                                   Arquitecto Cloud  Decide Soluciones
#
#       location            source date_posted contract_type
# 0       Madrid  Jobs By Workable  2023-08-06     Full-time
# 1       Madrid        Lumen Jobs  2023-09-03     Full-time
# 2       Madrid         Sartorius  2023-09-03     Full-time
# 3       Madrid        Greenhouse  2023-08-24     Full-time
# 4          NaN              Okta  2023-08-27     Full-time
# ...        ...               ...         ...           ...
# 16269      NaN          LinkedIn  2023-09-03     Full-time
# 16270   Madrid             BeBee  2023-08-30     Full-time
# 16271      NaN     Jobrapido.com  2023-09-03     Full-time
# 16272   Madrid             BeBee  2023-08-31     Full-time
# 16273   Madrid             BeBee  2023-08-26     Full-time
#
# [16274 rows x 16 columns]

# %%
df.to_csv("data/cleaned/spain_cleaned_data.csv", index = False, sep = ",")

# %%
################################################################################################################################
