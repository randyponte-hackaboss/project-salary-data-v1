# %% [markdown]
# ### Pipeline preprocesamiento de datos

# %%
# Omitir warnings
import warnings
warnings.filterwarnings("ignore")

# Librería creada
from libraries.preprocess import preprocess
from libraries.preprocess import pipeline

# %%
# %%time

df = pipeline.pipeline(funciones = pipeline.funciones)
df
# Out:
# CPU times: total: 3min 12s
# Wall time: 18min 26s
#                                                    job_id  experience  \
# 0       eyJqb2JfdGl0bGUiOiJBaSBBdWdtZW50ZWQgU29mdHdhcm...         5.0
# 1       eyJqb2JfdGl0bGUiOiJTb2Z0d2FyZSBEZXZlbG9wZXIgKE...         NaN
# 2       eyJqb2JfdGl0bGUiOiJTZW5pb3IgU29mdHdhcmUgRGV2ZW...         NaN
# 3       eyJqb2JfdGl0bGUiOiJTb2Z0d2FyZSBkZXZlbG9wZXIiLC...         NaN
# 4       eyJqb2JfdGl0bGUiOiJTQVAgQ1BRIFNvZnR3YXJlIERldm...         NaN
# ...                                                   ...         ...
# 213298  eyJqb2JfdGl0bGUiOiJTYWxlcyBPcGVyYXRpb25zIEFuYW...         4.0
# 213299  eyJqb2JfdGl0bGUiOiJEYXRhIEFuYWx5c3QgLSBQZXJpc2...         4.0
# 213300  eyJqb2JfdGl0bGUiOiJEYXRhIEFuYWx5c3QiLCJodGlkb2...         3.0
# 213301  eyJqb2JfdGl0bGUiOiJTYWxlcyBhbmQgTWFya2V0aW5nIE...         3.0
# 213302  eyJqb2JfdGl0bGUiOiJEYXRhIFNjaWVudGlzdCwgU2FsZX...        10.0
#
#        experience_level                                        description  \
# 0                Senior  100% remote job\n\nAi Augmented Software Devel...
# 1                   NaN  Welcome to Stack Builders! We’re an empathetic...
# 2                   NaN  About Lumen\nLumen is guided by our belief tha...
# 3                   NaN  About Cresory\n\nStart up Founded in 2021, Cre...
# 4                   NaN  We are looking for an experienced Software Dev...
# ...                 ...                                                ...
# 213298      Semi-Senior  Company Description\n\nAt ServiceNow, our tech...
# 213299      Semi-Senior  Who You'll Work With\n\nYou’ll work with our P...
# 213300      Semi-Senior  Databricks is looking for a Data Analyst to jo...
# 213301      Semi-Senior  Sales and Marketing Commissions Analytics Anal...
# 213302           Leader  What you get to do in this role:\n\nAs an inte...
#
#            job_specialization                         job_profile remote_work  \
# 0                         NaN                                 NaN    [Remoto]
# 1                         NaN                                 NaN    [Remoto]
# 2                         NaN                                 NaN         NaN
# 3          [Customer Success]                 [Gestión Operativa]         NaN
# 4       [APIs, Product Owner]  [Gestión Operativa, Desarrollador]   [Hibrido]
# ...                       ...                                 ...         ...
# 213298                    NaN                                 NaN    [Remoto]
# 213299                    NaN                                 NaN         NaN
# 213300                    NaN                                 NaN         NaN
# 213301             [Power BI]                     [Desarrollador]   [Hibrido]
# 213302                    NaN                                 NaN         NaN
#
#        tech_skills                                              title  \
# 0              NaN   Ai Augmented Software Developer Trilogy (Remote)
# 1             Ruby  Software Developer (English - Functional Progr...
# 2              NaN                          Senior Software Developer
# 3              NaN                                 Software developer
# 4              NaN                   SAP CPQ Software Developer (F/M)
# ...            ...                                                ...
# 213298     [Excel]                           Sales Operations Analyst
# 213299         NaN  Data Analyst - Periscope, Marketing & Sales So...
# 213300         NaN                                       Data Analyst
# 213301         NaN  Sales and Marketing Commissions Analytics Analyst
# 213302         NaN  Data Scientist, Sales Analytics (Machine Learn...
#
#               company_name    location  \
# 0                Crossover
# 1           Stack Builders       Spain
# 2         _external, Lumen       Spain
# 3                  Cresory
# 4                Sartorius       Spain
# ...                    ...         ...
# 213298          ServiceNow  Costa Rica
# 213299  McKinsey & Company  Costa Rica
# 213300          Databricks  Costa Rica
# 213301               INTEL  Costa Rica
# 213302          ServiceNow  Costa Rica
#
#                                                    source date_posted  \
# 0                                                 Pangian  2023-09-01
# 1                                        Jobs By Workable  2023-08-06
# 2                                              Lumen Jobs  2023-09-03
# 3                                               Wellfound  2023-09-03
# 4                                               Sartorius  2023-09-03
# ...                                                   ...         ...
# 213298                               Careers - ServiceNow  2023-09-04
# 213299                                            Karkidi  2023-09-04
# 213300  Jobs | Alkeon Capital Job Board - Alkeon Capit...  2023-09-04
# 213301                                              BeBee  2023-09-01
# 213302                                            Karkidi  2023-09-04
#
#        contract_type
# 0          Full-time
# 1          Full-time
# 2          Full-time
# 3         Internship
# 4          Full-time
# ...              ...
# 213298     Full-time
# 213299     Full-time
# 213300     Full-time
# 213301     Full-time
# 213302     Full-time
#
# [213303 rows x 14 columns]

# %%
################################################################################################################################
