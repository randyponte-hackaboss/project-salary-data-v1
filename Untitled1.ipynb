# %% [markdown]
# ## Prueba con googlesearch-python
#
# ```
# pip install googlesearch-python
# ```

# %%
from googlesearch import search
s = search("Data Science jobs spain", num_results = 10, sleep_interval = 5, advanced = True)

# %%
for i in s:
    print(i)
# Out:
# SearchResult(url=https://www.linkedin.com/jobs/search?keywords=Data+Scientist&geoId=105646813&trk=d_flagship3_salary_explorer, title=10000+ Data Scientist jobs in Spain (620 new), description=Today's top 10000+ Data Scientist jobs in Spain. Leverage your professional network, and get hired. New Data Scientist jobs added daily.)
# SearchResult(url=https://www.glassdoor.com/Job/spain-data-scientist-jobs-SRCH_IL.0,5_IN219_KO6,20.htm, title=581 data scientist Jobs in Spain, April 2024, description=581 Data scientist jobs in Spain ... Experience: 1-2 years of experience working as a data analyst, data scientist, or in a related field. Analyzing and ...)
# ...
