# %%
import pandas as pd

# %%
df = pd.read_csv("data/extracted/extraction_2024-04-17_spain.csv")

df
# Out:
#                                                    title  \
# 0                              Desarrollador de Software
# 1                              Desarrollador de Software
# 2                              Desarrollador de software
# 3                    Desarrollador/a de software en C/C+
# 4                                   Desarrollador de PHP
# ...                                                  ...
# 13500                Especialista Soporte Técnico Remoto
# 13501  Hasta 32k – 2 días remoto – Soporte Técnico N2...
# 13502  Especialista para actualizar material didáctic...
# 13503                      Técnico SR de redes Lan Cisco
# 13504                                Técnico Informático
#
#                             company_name                         location  \
# 0                    THE WISE SEEKER S.L                         Spain
# 1      WITRON Logistik + Informatik GmbH                 Madrid, Spain
# ...

# %%
pd.DataFrame(df["company_name"].unique(), columns = ["company_name"]).to_csv("empresas_v1.csv", index = False)

# %%
df.shape
# Out:
# (13505, 16)
