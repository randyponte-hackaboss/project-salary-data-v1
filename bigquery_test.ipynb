# %%
import pandas as pd

df = pd.read_csv("bigquery_1.csv")

# df = df.dropna()

# df.to_csv("bigquery_3.csv", index = False)

df.head(3)
# Out:
#                                               job_id  \
# 0  eyJqb2JfdGl0bGUiOiJEZXNhcnJvbGxhZG9yIGRlIFNvZn...
# 1  eyJqb2JfdGl0bGUiOiJEZXNhcnJvbGxhZG9yIGRlIFNvZn...
# 2  eyJqb2JfdGl0bGUiOiJEZXNhcnJvbGxhZG9yIGRlIHNvZn...
#
#                        title                       company_name location  \
# 0  Desarrollador de Software                THE WISE SEEKER S.L    Spain
# 1  Desarrollador de Software  WITRON Logistik + Informatik GmbH   Madrid
# 2  Desarrollador de software                                CBT    Getxo
#
#        source                                        description date_posted  \
# 0  Infoempleo  - Desarrollar soluciones de software asegurand...  2024-04-17
# 1   Glassdoor  Als Teil der WITRON Gruppe plant und realisier...  2024-03-20
# 2    LinkedIn  CBT es una empresa del Grupo Innovalia dedicad...  2024-04-15
#
#   contract_type                       tech_skills  experience  \
# 0     Full-time                                []         NaN
# ...

# %%
df["tech_skills"]
# Out:
# 0                                                       []
# 1                                                  ['SQL']
# 2                         ['Angular', 'Android', 'iPhone']
# 3                                         ['Jira', 'REST']
# 4        ['CSS', 'JavaScript', 'JSON', 'PHP', 'Javascri...
#                                ...
# 22189                           ['SQL', 'CRM', 'Dynamics']
# 22190                      ['Aceptación', 'GitHub', 'DOS']
# 22191                                                   []
# 22192                          ['ERP', 'Microsoft', 'SAP']
# 22193                                  ['Azure', 'Prisma']
# Name: tech_skills, Length: 22194, dtype: object

# %%
for x in df["tech_skills"].value_counts().index:
    print(x)
# Out:
# []
# ['Integración']
# ['SAP']
# ['DOS']
# ['Marketing']
# ['Linux']
# ['Java']
# ['SQL']
# ['Microsoft']
# ['Funcionales']
# ['Python']
# ['Cisco']
# ['Excel']
# ['Android']
# ['COBOL']
# ['.NET']
# ['Angular']
# ['Oracle']
# ['Integración', 'SAP']
# ['PHP']
# ['ERP']
# ['AutoCAD']
# ['ITIL']
# ['Management']
# ['Azure']
# ['VMware']
# ['Java', 'Spring']
# ['Jira']
# ['Engineering']
# ['Legal']
# ['Freelance']
# ['Funcionales', 'Integración']
# ['Funcionales', 'SAP']
# ['Branding']
# ['AWS']
# ['Integración', 'Java']
# ['Helpdesk']
# ['.NET', 'SQL']
# ['Marketing', 'SEO']
# ['Integración', 'Linux']
# ['Sharepoint']
# ['Swift']
# ['GIT', 'Git']
# ['Freelance', 'SAP']
# ['DOS', 'SAP']
# ['Oracle', 'SQL']
# ['Analytics']
# ['DOS', 'Legal']
# ['Java', 'Microservicios', 'Spring']
# ['Estadística']
# ['JavaScript', 'Javascript']
# ['Azure', 'Microsoft']
# ['CRM']
# ['Funcionales', 'Integración', 'SAP']
# ['Integración', 'DOS']
# ['Java', 'Microservicios']
# ['Integración', 'SQL']
# ...
